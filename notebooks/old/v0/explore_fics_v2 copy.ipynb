# %% [markdown]
# ## Installations

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from tqdm import tqdm
import time
import os
import os
import re
from collections import Counter
import pickle
import lichess.api
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from tslearn.clustering import TimeSeriesKMeans
from tslearn.clustering import TimeSeriesKMeans
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tslearn.clustering import TimeSeriesKMeans, KShape, KernelKMeans
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from matplotlib.patches import ConnectionPatch
import matplotlib.pyplot as plt
import numpy as np
import scipy.spatial.distance as dist
from warnings import filterwarnings
from random import sample
from datetime import datetime, timezone
import os
import pandas as pd
from sklearn.metrics import classification_report
from tslearn.utils import to_time_series_dataset
from tslearn.preprocessing import TimeSeriesScalerMeanVariance
from tslearn.clustering import TimeSeriesKMeans, silhouette_score
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns  

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, roc_auc_score

try:
  from tslearn.clustering import TimeSeriesKMeans
  from tslearn.clustering import silhouette_score
except:
  import sys
  # !{sys.executable} -m pip install tslearn
  from tslearn.clustering import TimeSeriesKMeans
  from tslearn.clustering import silhouette_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import time
from sklearn import metrics
# Avoid showing warnings to keep the notebook outputs clean.
filterwarnings("ignore")
# Out:
# /home/ariel/anaconda3/envs/ml/lib/python3.12/site-packages/tslearn/bases/bases.py:15: UserWarning: h5py not installed, hdf5 features will not be supported.
# Install h5py to use hdf5 features: http://docs.h5py.org/
#   warn(h5py_msg)

# %%
PROJECT_PATH="/home/ariel/Documents/chess_improments_patterns"
MAX_T=50
RISING_LABEL=1

# %% [markdown]
# ## Methods

# %%
def read_file(file):
    df=pd.read_csv(file)

    return df


def get_all_players(df):
    all_whites=list(set(sorted(df["White"])))
    all_whites=sorted(all_whites)
    all_black=list(set(sorted(df["Black"])))
    all_black=sorted(all_black)
    all_players=list(set(all_whites+all_black))
    return all_players
def get_events_for_player(df,player):
    return Counter(list(df[(df["White"]==player)|(df["Black"]==player)]["Event"]))
def get_games_for_player(df,player):
    return df[(df["White"]==player)|(df["Black"]==player)]

def get_years_for_player(df,player):
    return dict(Counter(list(df[(df["White"]==player)|(df["Black"]==player)]["Year"])))
def get_years_for_player_game(df,player,game):
    return dict(Counter(list(df[((df["White"]==player)|(df["Black"]==player))&(df["Event"]==game)]["Year"])))
def get_players(df):
    w=list(df["White"])
    b=list(df["Black"])
    all=list(set((w+b)))
    return all

def get_games_for_player(df,player):
    player_black_df=df[df["Black"]==player]
    player_black_df=player_black_df[["UTCDate","BlackElo","UTCTime"]]
    player_black_df.rename(columns={'BlackElo':'Elo'},inplace=True)

    player_white_df=df[df["White"]==player]
    player_white_df=player_white_df[["UTCDate","WhiteElo","UTCTime"]]
    player_white_df.rename(columns={'WhiteElo':'Elo'},inplace=True)

    return pd.concat([player_black_df,player_white_df]).sort_values(by='UTCDate')


def date_to_num(date_str):
    # Parse the date string to datetime object
    date_obj = datetime.strptime(date_str, "%Y.%m.%d %H:%M:%S")

    # Convert the datetime object to Unix timestamp (seconds since epoch)
    unix_timestamp = date_obj.replace(tzinfo=timezone.utc).timestamp()
    return unix_timestamp

def get_players_atleast_x_games_type(x,game_type,df):

    df_c=(df[df["Event"]==" Blitz "])
    w=dict(df_c["White"].value_counts())
    b=dict(df_c["Black"].value_counts())
    all={}
    all=w
    for k,v in b.items():
        all[k]=all.get(k,0)+v
    h=[]
    for k,v in w.items():
        if v>200:
            h.append(k)
    len(h)

    #
    df=df[(df["White"].isin(h))|(df["Black"].isin(h))]

    #
    df1=df[(df["White"].isin(h))&(df["Black"].isin(h))]
    df1=df1[["White","WhiteElo","UTCDate","UTCTime"]].rename(columns={"White":"Player","WhiteElo":"Elo"})

    df2=df[(df["White"].isin(h))&(~df["Black"].isin(h))]
    df2=df2[["White","WhiteElo","UTCDate","UTCTime"]].rename(columns={"White":"Player","WhiteElo":"Elo"})

    #
    df3=df[(~df["White"].isin(h))&(df["Black"].isin(h))]
    df3=df3[["Black","BlackElo","UTCDate","UTCTime"]].rename(columns={"Black":"Player","BlackElo":"Elo"})

    #
    df4=df[(df["White"].isin(h))&(df["Black"].isin(h))]
    df4=df4[["Black","BlackElo","UTCDate","UTCTime"]].rename(columns={"Black":"Player","BlackElo":"Elo"})

    #
    df=pd.concat([df1,df2,df3,df4])
    return df

def classify(df,test_size,model,name):
    train, test = train_test_split(df, test_size=test_size)
    y_train, y_test = train['label'], test['label']
    X_train, X_test = train.drop('label', axis=1), test.drop('label', axis=1)
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    print("-"*100)
    print("Model name:",name)
    print("accuracy_score:",accuracy_score(y_test,y_predict))
    print("roc_auc_score:",roc_auc_score(y_test,y_predict))
    print("precision_score:",precision_score(y_test,y_predict))
    print("f1_score:",f1_score(y_test,y_predict))
    RocCurveDisplay.from_estimator(model, X_test, y_test)
    print("-"*100)
    
    return {
        'model':model,
        'accuracy':accuracy_score(y_test,y_predict),
        'precision':precision_score(y_test,y_predict),
        'recall':recall_score(y_test,y_predict),
        'f1':f1_score(y_test,y_predict),
        'name':name
           }
    
def compare_model_results(results):

    a, p, r, f,names = [], [], [], [],[]
    for res in results:
        a.append(res["accuracy"])
        p.append(res["precision"])
        r.append(res["recall"])
        f.append(res["f1"])
        names.append(res["name"])

    #
    model_score = pd.DataFrame([a,p,r,f],
                 columns = names).T.sort_values(by=3, ascending=False).rename(columns={0:'Accuracy', 1: 'Precision', 2: 'Recall', 3: 'F1',}).round(4) 
    # Create a heatmap of the summary
    plt.figure(figsize= (10,10))
    sns.heatmap(model_score, annot=True, cmap = 'coolwarm')
    plt.show()

# %%
with open(f"{PROJECT_PATH}/data/fics/dataset_raw/player_series_labels_v2_150_euclidean.pkl", 'rb') as f:
    player_series_labels=pickle.load(f)
players=set(player_series_labels.keys())

# %%
data_dict={
    "label":[]
}
for p in player_series_labels:
    num_games=len(player_series_labels[p]['games'])
    data_dict["label"].append(int(player_series_labels[p]["label"][0]==1))
    for i in range(0,min(num_games,MAX_T)):
        data_dict["t="+str(i)+""]=data_dict.get("t="+str(i),[])
        data_dict["t="+str(i)+""].append(player_series_labels[p]['games'][i])

df=pd.DataFrame.from_dict(data_dict)

# %% [markdown]
# ## Baseline classification(just use points no features)

# %%
df
# Out:
#       label   t=0   t=1   t=2   t=3   t=4   t=5   t=6   t=7   t=8  ...  t=40  \
# 0         0  1634  1653  1651  1644  1643  1653  1651  1634  1633  ...  1581
# 1         0  1406  1399  1408  1417  1426  1434  1441  1448  1455  ...  1423
# 2         0  1619  1619  1615  1609  1612  1621  1623  1625  1615  ...  1591
# 3         0  1661  1655  1649  1643  1651  1640  1648  1656  1665  ...  1668
# 4         0  1764  1755  1753  1747  1740  1747  1740  1733  1728  ...  1783
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 5925      0  1352  1343  1338  1359  1351  1349  1339  1331  1348  ...  1324
# 5926      0  1544  1535  1543  1550  1557  1564  1554  1561  1568  ...  1556
# 5927      0  1262  1235  1258  1250  1248  1243  1272  1262  1250  ...  1263
# 5928      0  1353  1352  1352  1351  1351  1351  1351  1338  1338  ...  1305
# 5929      0  1501  1508  1504  1513  1519  1514  1521  1517  1510  ...  1542
#
#       t=41  t=42  t=43  t=44  t=45  t=46  t=47  t=48  t=49
# 0     1573  1578  1576  1573  1569  1565  1558  1556  1554
# 1     1432  1442  1438  1434  1446  1456  1446  1457  1452
# 2     1600  1605  1615  1605  1595  1599  1604  1596  1605
# 3     1675  1665  1671  1662  1665  1668  1674  1676  1667
# 4     1810  1787  1766  1751  1738  1734  1740  1739  1756
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 5925  1322  1318  1306  1330  1325  1320  1309  1300  1297
# 5926  1547  1554  1561  1568  1558  1549  1556  1547  1538
# 5927  1259  1252  1255  1269  1264  1259  1258  1257  1258
# 5928  1297  1328  1327  1326  1324  1324  1324  1323  1323
# 5929  1531  1522  1530  1525  1518  1526  1536  1545  1560
#
# [5930 rows x 51 columns]

# %%
models=[]
models_names=[]

# %%
df=pd.DataFrame.from_dict(data_dict)

# %% [markdown]
# ##  find features

# %%
chunksize = 10 ** 7
rich_players_data={p:[] for p in players}

with pd.read_csv(f"{PROJECT_PATH}/data/fics/dataset_raw/chess-games-rated-standard-filtered.csv", chunksize=chunksize) as reader:
    for chunk in reader:
        print("read")
        chunk=chunk[(chunk["White"].isin(players))|(chunk["Black"].isin(players))]
        chunk["Year"]=chunk["Date"].apply(lambda r:int(r.split(".")[0]))
        chunk["Month"]=chunk["Date"].apply(lambda r:int(r.split(".")[1]))
        chunk["Day"]=chunk["Date"].apply(lambda r:int(r.split(".")[2]))
        chunk["Timestamp"]=(chunk["Date"]+" "+chunk["Time"]).apply(lambda r:date_to_num(r))
        for p in tqdm(players):
            ts=player_series_labels[p]['ts']
            cond_1=(chunk["Timestamp"]>=min(ts))
            cond_2=(chunk["Timestamp"]<=max(ts))
            cond_3=((chunk["White"]==p)|(chunk["Black"]==p))
            chunk_filtered=chunk[cond_1&cond_2&cond_3]
            rich_players_data[p].append(chunk_filtered)

for p in players:
    rich_players_data[p]=pd.concat(rich_players_data[p])

with open(f"{PROJECT_PATH}/data/fics/dataset_raw/player_series_labels_v2_150_euclidean_rich.pkl", 'wb+') as f:
    pickle.dump(rich_players_data,f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 chunksize = 10 ** 7
# ----> 2 rich_players_data={p:[] for p in players}
#       4 with pd.read_csv(f"{PROJECT_PATH}/data/fics/dataset_raw/chess-games-rated-standard-filtered.csv", chunksize=chunksize) as reader:
#       5     for chunk in reader:
#
# NameError: name 'players' is not defined

# %%
with open(f"{PROJECT_PATH}/data/fics/dataset_raw/player_series_labels_v2_150_euclidean_rich.pkl", 'rb') as f:
    rich_players_data=pickle.load(f)

# %%
with open(f"{PROJECT_PATH}/data/fics/dataset_raw/player_series_labels_v2_150_euclidean.pkl", 'rb') as f:
    player_series_labels=pickle.load(f)
players=set(player_series_labels.keys())

# %%
# player_series_labels

for p in list(rich_players_data.keys()): 
    curr=rich_players_data[p]
    curr=curr.sort_values(by=["Timestamp"]).reset_index()
    curr=curr[curr.index<MAX_T]
    rich_players_data[p]=curr

# %%
example=rich_players_data[list(rich_players_data.keys())[0]]

# %%
def get_freq(my_str,c):
    return ( sum([int(s==c) for s in my_str]))

# %%
features_dict={
    'white_to_black_ratio':[],
    'label':[],
    'player_elo_mean':[],
    'opponent_elo_mean':[],
    'elo_diff_mean':[],
    'total_won':[],
    'total_lost':[],
    'total_draw':[],
    'avg_number_of_moves':[]

}

for p in list(rich_players_data.keys()): 
    
    # count
    curr=rich_players_data[p]
    # print(curr.columns)
    curr_w=curr[curr["White"]==p]
    curr_b=curr[curr["Black"]==p]
    total_number_of_moves_w=sum(curr_w.Moves.apply(lambda c:get_freq(c,"|")))
    total_number_of_moves_b=sum(curr_b.Moves.apply(lambda c:get_freq(c,"|")))

    avg__number_of_moves=(total_number_of_moves_w+total_number_of_moves_b)/len(curr)
    features_dict["avg_number_of_moves"].append(avg__number_of_moves)




    total_won_as_w=len(curr[(curr["Result"]=="1-0")&(curr["White"]==p)])
    total_lost_as_w=len(curr[(curr["Result"]=="0-1")&(curr["White"]==p)])
    total_won_as_b=len(curr[(curr["Result"]=="0-1")&(curr["Black"]==p)])
    total_lost_as_b=len(curr[(curr["Result"]=="1-0")&(curr["Black"]==p)])
    total_won=total_won_as_w+total_won_as_b
    total_lost=total_lost_as_w+total_lost_as_b
    total_draw=len(curr)-total_won-total_lost
    features_dict["total_won"].append(total_won)
    features_dict["total_lost"].append(total_lost)
    features_dict["total_draw"].append(total_draw)
    total_number_of_moves=sum(curr.Moves.apply(lambda c:get_freq(c,"|")))
    avg__number_of_moves=total_number_of_moves/len(curr)

    #
    black_freq=dict(Counter(curr["Black"]))
    white_freq=dict(Counter(curr["White"]))
    result_freq=dict(Counter(curr["Result"]))
    white_to_black_ratio=white_freq.get(p,0)/(MAX_T)
    features_dict["white_to_black_ratio"].append(white_to_black_ratio)
    
    #
    player_elo=list(curr[curr["White"]==p]["WhiteElo"])+list(curr[curr["Black"]==p]["BlackElo"])
    opponent_elo=list(curr[curr["White"]!=p]["WhiteElo"])+list(curr[curr["Black"]!=p]["BlackElo"])
    player_elo_mean=np.mean(player_elo)
    opponent_elo_mean=np.mean(opponent_elo)
    elo_diff=[r["WhiteElo"]-r["BlackElo"] for (_,r) in curr.iterrows()]
    elo_diff_mean=sum(elo_diff)/len(curr)
    #
    features_dict["elo_diff_mean"].append(elo_diff_mean)
    features_dict["player_elo_mean"].append(player_elo_mean)
    features_dict["opponent_elo_mean"].append(opponent_elo_mean)



    # label
    label=player_series_labels[p]['label'][0]
    label=int(player_series_labels[p]["label"][0]==RISING_LABEL)
    features_dict["label"].append(label)


df=pd.DataFrame.from_dict(features_dict)
df
# Out:
#       white_to_black_ratio  label  player_elo_mean  opponent_elo_mean  \
# 0                     0.50      0          1625.56            1569.84
# 1                     0.48      0          1580.46            1687.72
# 2                     0.46      0          1465.70            1480.20
# 3                     0.46      1          1746.82            1561.62
# 4                     0.50      0          1630.56            1703.84
# ...                    ...    ...              ...                ...
# 5925                  0.50      0          1754.94            1762.34
# 5926                  0.54      0          1639.98            1592.58
# 5927                  0.50      0          1558.88            1523.56
# 5928                  0.48      1          1732.62            1220.80
# 5929                  0.48      0          1674.18            1667.58
#
#       elo_diff_mean  total_won  total_lost  total_draw  avg_number_of_moves
# 0             26.88         32          18           0                46.70
# 1              8.26         19          30           1                42.18
# 2            -21.66         20          29           1                48.28
# 3            -14.76         37           9           4                68.76
# 4            -10.16         16          29           5                66.16
# ...             ...        ...         ...         ...                  ...
# 5925           5.88         24          22           4                76.20
# 5926           1.52         26          21           3                55.12
# 5927           2.60         25          24           1                53.38
# 5928          -0.14         47           3           0                61.24
# 5929         -12.16         26          23           1                58.36
#
# [5930 rows x 9 columns]

# %%
models=[]

# %% [markdown]
# #### logistic regression

# %%
from sklearn.linear_model import LogisticRegression
models.append(classify(df,0.2,LogisticRegression(),"logistic regression"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: logistic regression
# accuracy_score: 0.6812816188870152
# roc_auc_score: 0.5718097812421423
# precision_score: 0.6095890410958904
# f1_score: 0.32014388489208634
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Support vector machines

# %%
from sklearn.svm import SVC
models.append(classify(df,0.2,SVC(probability =True),"Support vector machine"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: Support vector machine
# accuracy_score: 0.6720067453625632
# roc_auc_score: 0.5
# precision_score: 0.0
# f1_score: 0.0
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Random Forrest

# %%
from sklearn.ensemble import RandomForestClassifier 
models.append(classify(df,0.2,RandomForestClassifier(n_estimators=100, random_state=42),"basic random forrest"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: basic random forrest
# accuracy_score: 0.6391231028667791
# roc_auc_score: 0.5417785563815255
# precision_score: 0.4756756756756757
# f1_score: 0.2913907284768212
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
models.append(classify(df,0.2,DecisionTreeClassifier(random_state=42),"decision tree"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: decision tree
# accuracy_score: 0.5893760539629005
# roc_auc_score: 0.5579203765873595
# precision_score: 0.44755244755244755
# f1_score: 0.44087256027554533
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB  # For Gaussian Naive Bayes
models.append(classify(df,0.2,GaussianNB(),"Gaussian Naive Bayes"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: Gaussian Naive Bayes
# accuracy_score: 0.6408094435075885
# roc_auc_score: 0.5062295061450277
# precision_score: 0.4032258064516129
# f1_score: 0.10504201680672269
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### KNN

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier  
models.append(classify(df,0.2,KNeighborsClassifier(2),"KNeighborsClassifier"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: KNeighborsClassifier
# accuracy_score: 0.6374367622259697
# roc_auc_score: 0.5132455485490096
# precision_score: 0.39097744360902253
# f1_score: 0.1947565543071161
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### AdaBoostClassifier

# %%
models.append(classify(df,0.2,AdaBoostClassifier(),"AdaBoostClassifier"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: AdaBoostClassifier
# accuracy_score: 0.6795952782462057
# roc_auc_score: 0.5463125625426879
# precision_score: 0.6206896551724138
# f1_score: 0.22131147540983606
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### CatBoostClassifier

# %%
models.append(classify(df,0.2,CatBoostClassifier(),"CatBoostClassifier"))
# Out:
# Learning rate set to 0.020028
# 0:	learn: 0.6903621	total: 48.3ms	remaining: 48.3s
# 1:	learn: 0.6879902	total: 49.9ms	remaining: 24.9s
# 2:	learn: 0.6856336	total: 50.8ms	remaining: 16.9s
# 3:	learn: 0.6835120	total: 51.6ms	remaining: 12.9s
# 4:	learn: 0.6814248	total: 52.7ms	remaining: 10.5s
# 5:	learn: 0.6792722	total: 53.5ms	remaining: 8.87s
# 6:	learn: 0.6770875	total: 57.4ms	remaining: 8.15s
# 7:	learn: 0.6749515	total: 58.7ms	remaining: 7.28s
# 8:	learn: 0.6729750	total: 60ms	remaining: 6.61s
# 9:	learn: 0.6708741	total: 61.2ms	remaining: 6.06s
# 10:	learn: 0.6688988	total: 62.3ms	remaining: 5.6s
# 11:	learn: 0.6672999	total: 63.2ms	remaining: 5.21s
# 12:	learn: 0.6657721	total: 64.4ms	remaining: 4.89s
# 13:	learn: 0.6640341	total: 65.3ms	remaining: 4.6s
# 14:	learn: 0.6625827	total: 66.4ms	remaining: 4.36s
# 15:	learn: 0.6610038	total: 67.3ms	remaining: 4.14s
# 16:	learn: 0.6594118	total: 68.3ms	remaining: 3.95s
# 17:	learn: 0.6582013	total: 69.4ms	remaining: 3.79s
# 18:	learn: 0.6567603	total: 70.3ms	remaining: 3.63s
# 19:	learn: 0.6556009	total: 71.5ms	remaining: 3.5s
# 20:	learn: 0.6542372	total: 72.5ms	remaining: 3.38s
# 21:	learn: 0.6528135	total: 73.5ms	remaining: 3.27s
# 22:	learn: 0.6515408	total: 74.5ms	remaining: 3.16s
# 23:	learn: 0.6503323	total: 75.4ms	remaining: 3.07s
# 24:	learn: 0.6492403	total: 76.4ms	remaining: 2.98s
# 25:	learn: 0.6478942	total: 77.3ms	remaining: 2.9s
# 26:	learn: 0.6467102	total: 78.3ms	remaining: 2.82s
# 27:	learn: 0.6455165	total: 79.3ms	remaining: 2.75s
# 28:	learn: 0.6447404	total: 80.4ms	remaining: 2.69s
# 29:	learn: 0.6436679	total: 81.5ms	remaining: 2.63s
# 30:	learn: 0.6426758	total: 82.6ms	remaining: 2.58s
# 31:	learn: 0.6417375	total: 83.7ms	remaining: 2.53s
# 32:	learn: 0.6407962	total: 84.8ms	remaining: 2.48s
# 33:	learn: 0.6402233	total: 85.6ms	remaining: 2.43s
# 34:	learn: 0.6394963	total: 86.6ms	remaining: 2.39s
# 35:	learn: 0.6385304	total: 87.6ms	remaining: 2.35s
# 36:	learn: 0.6378850	total: 88.6ms	remaining: 2.31s
# 37:	learn: 0.6370797	total: 89.7ms	remaining: 2.27s
# 38:	learn: 0.6364816	total: 90.7ms	remaining: 2.23s
# 39:	learn: 0.6357045	total: 91.8ms	remaining: 2.2s
# 40:	learn: 0.6350308	total: 92.8ms	remaining: 2.17s
# 41:	learn: 0.6342288	total: 93.9ms	remaining: 2.14s
# 42:	learn: 0.6335860	total: 94.9ms	remaining: 2.11s
# 43:	learn: 0.6328674	total: 95.9ms	remaining: 2.08s
# 44:	learn: 0.6320900	total: 96.9ms	remaining: 2.06s
# 45:	learn: 0.6314685	total: 98ms	remaining: 2.03s
# 46:	learn: 0.6306151	total: 99.2ms	remaining: 2.01s
# 47:	learn: 0.6299575	total: 100ms	remaining: 1.99s
# 48:	learn: 0.6293889	total: 102ms	remaining: 1.97s
# 49:	learn: 0.6288241	total: 103ms	remaining: 1.95s
# 50:	learn: 0.6281527	total: 104ms	remaining: 1.93s
# 51:	learn: 0.6274477	total: 105ms	remaining: 1.91s
# 52:	learn: 0.6270265	total: 106ms	remaining: 1.89s
# 53:	learn: 0.6265373	total: 107ms	remaining: 1.88s
# 54:	learn: 0.6260400	total: 108ms	remaining: 1.86s
# 55:	learn: 0.6254624	total: 109ms	remaining: 1.84s
# 56:	learn: 0.6249188	total: 110ms	remaining: 1.82s
# 57:	learn: 0.6241799	total: 111ms	remaining: 1.8s
# 58:	learn: 0.6238317	total: 112ms	remaining: 1.79s
# 59:	learn: 0.6232869	total: 113ms	remaining: 1.77s
# 60:	learn: 0.6228408	total: 114ms	remaining: 1.76s
# 61:	learn: 0.6224030	total: 115ms	remaining: 1.74s
# 62:	learn: 0.6218903	total: 116ms	remaining: 1.73s
# 63:	learn: 0.6214094	total: 118ms	remaining: 1.72s
# 64:	learn: 0.6208766	total: 119ms	remaining: 1.71s
# 65:	learn: 0.6203919	total: 120ms	remaining: 1.69s
# 66:	learn: 0.6199151	total: 121ms	remaining: 1.68s
# 67:	learn: 0.6196439	total: 122ms	remaining: 1.67s
# 68:	learn: 0.6192632	total: 123ms	remaining: 1.66s
# 69:	learn: 0.6189063	total: 124ms	remaining: 1.65s
# 70:	learn: 0.6183383	total: 125ms	remaining: 1.63s
# 71:	learn: 0.6179169	total: 126ms	remaining: 1.62s
# 72:	learn: 0.6173246	total: 127ms	remaining: 1.61s
# 73:	learn: 0.6168691	total: 128ms	remaining: 1.6s
# 74:	learn: 0.6164694	total: 129ms	remaining: 1.59s
# 75:	learn: 0.6160283	total: 130ms	remaining: 1.58s
# 76:	learn: 0.6158448	total: 131ms	remaining: 1.57s
# 77:	learn: 0.6154853	total: 133ms	remaining: 1.57s
# 78:	learn: 0.6151509	total: 134ms	remaining: 1.56s
# 79:	learn: 0.6148972	total: 135ms	remaining: 1.55s
# 80:	learn: 0.6146691	total: 136ms	remaining: 1.54s
# 81:	learn: 0.6144164	total: 137ms	remaining: 1.53s
# 82:	learn: 0.6141786	total: 138ms	remaining: 1.52s
# 83:	learn: 0.6138740	total: 139ms	remaining: 1.52s
# 84:	learn: 0.6135865	total: 140ms	remaining: 1.51s
# 85:	learn: 0.6133065	total: 141ms	remaining: 1.5s
# 86:	learn: 0.6131221	total: 142ms	remaining: 1.49s
# 87:	learn: 0.6127791	total: 143ms	remaining: 1.48s
# 88:	learn: 0.6123058	total: 144ms	remaining: 1.48s
# 89:	learn: 0.6119834	total: 145ms	remaining: 1.47s
# 90:	learn: 0.6115769	total: 147ms	remaining: 1.46s
# 91:	learn: 0.6112300	total: 148ms	remaining: 1.46s
# 92:	learn: 0.6108684	total: 149ms	remaining: 1.45s
# 93:	learn: 0.6105365	total: 150ms	remaining: 1.44s
# 94:	learn: 0.6101972	total: 151ms	remaining: 1.44s
# 95:	learn: 0.6098373	total: 152ms	remaining: 1.43s
# 96:	learn: 0.6095732	total: 153ms	remaining: 1.42s
# 97:	learn: 0.6093614	total: 154ms	remaining: 1.42s
# 98:	learn: 0.6090392	total: 155ms	remaining: 1.41s
# 99:	learn: 0.6089047	total: 156ms	remaining: 1.41s
# 100:	learn: 0.6084289	total: 157ms	remaining: 1.4s
# 101:	learn: 0.6081987	total: 159ms	remaining: 1.4s
# 102:	learn: 0.6080220	total: 160ms	remaining: 1.39s
# 103:	learn: 0.6077362	total: 161ms	remaining: 1.39s
# 104:	learn: 0.6073650	total: 162ms	remaining: 1.38s
# 105:	learn: 0.6071259	total: 163ms	remaining: 1.38s
# 106:	learn: 0.6067861	total: 164ms	remaining: 1.37s
# 107:	learn: 0.6065640	total: 165ms	remaining: 1.36s
# 108:	learn: 0.6062933	total: 166ms	remaining: 1.36s
# 109:	learn: 0.6060461	total: 167ms	remaining: 1.35s
# 110:	learn: 0.6056008	total: 168ms	remaining: 1.35s
# 111:	learn: 0.6052657	total: 169ms	remaining: 1.34s
# 112:	learn: 0.6048586	total: 170ms	remaining: 1.34s
# 113:	learn: 0.6046666	total: 171ms	remaining: 1.33s
# 114:	learn: 0.6043172	total: 172ms	remaining: 1.33s
# 115:	learn: 0.6039086	total: 174ms	remaining: 1.32s
# 116:	learn: 0.6036243	total: 175ms	remaining: 1.32s
# 117:	learn: 0.6032739	total: 176ms	remaining: 1.31s
# 118:	learn: 0.6029109	total: 177ms	remaining: 1.31s
# 119:	learn: 0.6025000	total: 178ms	remaining: 1.3s
# 120:	learn: 0.6023116	total: 179ms	remaining: 1.3s
# 121:	learn: 0.6020744	total: 180ms	remaining: 1.29s
# 122:	learn: 0.6019249	total: 181ms	remaining: 1.29s
# 123:	learn: 0.6016761	total: 182ms	remaining: 1.29s
# 124:	learn: 0.6013810	total: 183ms	remaining: 1.28s
# 125:	learn: 0.6011074	total: 184ms	remaining: 1.28s
# 126:	learn: 0.6008785	total: 186ms	remaining: 1.28s
# 127:	learn: 0.6007764	total: 187ms	remaining: 1.27s
# 128:	learn: 0.6005502	total: 188ms	remaining: 1.27s
# 129:	learn: 0.6002003	total: 189ms	remaining: 1.26s
# 130:	learn: 0.5999087	total: 190ms	remaining: 1.26s
# 131:	learn: 0.5995347	total: 191ms	remaining: 1.26s
# 132:	learn: 0.5992520	total: 192ms	remaining: 1.25s
# 133:	learn: 0.5990624	total: 194ms	remaining: 1.25s
# 134:	learn: 0.5989032	total: 195ms	remaining: 1.25s
# 135:	learn: 0.5986387	total: 196ms	remaining: 1.25s
# 136:	learn: 0.5983080	total: 197ms	remaining: 1.24s
# 137:	learn: 0.5980289	total: 198ms	remaining: 1.24s
# 138:	learn: 0.5976874	total: 199ms	remaining: 1.24s
# 139:	learn: 0.5974051	total: 201ms	remaining: 1.23s
# 140:	learn: 0.5971221	total: 202ms	remaining: 1.23s
# 141:	learn: 0.5969766	total: 203ms	remaining: 1.23s
# 142:	learn: 0.5968840	total: 204ms	remaining: 1.22s
# 143:	learn: 0.5965134	total: 205ms	remaining: 1.22s
# 144:	learn: 0.5961385	total: 206ms	remaining: 1.22s
# 145:	learn: 0.5958418	total: 207ms	remaining: 1.21s
# 146:	learn: 0.5955363	total: 209ms	remaining: 1.21s
# 147:	learn: 0.5954256	total: 210ms	remaining: 1.21s
# 148:	learn: 0.5951557	total: 211ms	remaining: 1.2s
# 149:	learn: 0.5949694	total: 212ms	remaining: 1.2s
# 150:	learn: 0.5947295	total: 213ms	remaining: 1.2s
# 151:	learn: 0.5945352	total: 214ms	remaining: 1.19s
# 152:	learn: 0.5944228	total: 215ms	remaining: 1.19s
# 153:	learn: 0.5941715	total: 217ms	remaining: 1.19s
# 154:	learn: 0.5940557	total: 218ms	remaining: 1.19s
# 155:	learn: 0.5938789	total: 219ms	remaining: 1.19s
# 156:	learn: 0.5936758	total: 220ms	remaining: 1.18s
# 157:	learn: 0.5934178	total: 222ms	remaining: 1.18s
# 158:	learn: 0.5931753	total: 223ms	remaining: 1.18s
# 159:	learn: 0.5928983	total: 224ms	remaining: 1.17s
# 160:	learn: 0.5926897	total: 225ms	remaining: 1.17s
# 161:	learn: 0.5923380	total: 226ms	remaining: 1.17s
# 162:	learn: 0.5921445	total: 227ms	remaining: 1.17s
# 163:	learn: 0.5919448	total: 228ms	remaining: 1.16s
# 164:	learn: 0.5918075	total: 229ms	remaining: 1.16s
# 165:	learn: 0.5915628	total: 230ms	remaining: 1.16s
# 166:	learn: 0.5912784	total: 232ms	remaining: 1.16s
# 167:	learn: 0.5911865	total: 233ms	remaining: 1.15s
# 168:	learn: 0.5909936	total: 234ms	remaining: 1.15s
# 169:	learn: 0.5907299	total: 235ms	remaining: 1.15s
# 170:	learn: 0.5905137	total: 237ms	remaining: 1.15s
# 171:	learn: 0.5904257	total: 238ms	remaining: 1.15s
# 172:	learn: 0.5901018	total: 239ms	remaining: 1.14s
# 173:	learn: 0.5898832	total: 240ms	remaining: 1.14s
# 174:	learn: 0.5895320	total: 242ms	remaining: 1.14s
# 175:	learn: 0.5893255	total: 243ms	remaining: 1.14s
# 176:	learn: 0.5891734	total: 244ms	remaining: 1.14s
# 177:	learn: 0.5889347	total: 245ms	remaining: 1.13s
# 178:	learn: 0.5887153	total: 246ms	remaining: 1.13s
# 179:	learn: 0.5886109	total: 248ms	remaining: 1.13s
# 180:	learn: 0.5884205	total: 249ms	remaining: 1.13s
# 181:	learn: 0.5882975	total: 250ms	remaining: 1.12s
# 182:	learn: 0.5882125	total: 251ms	remaining: 1.12s
# 183:	learn: 0.5878904	total: 252ms	remaining: 1.12s
# 184:	learn: 0.5876823	total: 254ms	remaining: 1.12s
# 185:	learn: 0.5874980	total: 255ms	remaining: 1.11s
# 186:	learn: 0.5872862	total: 256ms	remaining: 1.11s
# 187:	learn: 0.5870936	total: 257ms	remaining: 1.11s
# 188:	learn: 0.5868927	total: 259ms	remaining: 1.11s
# 189:	learn: 0.5867092	total: 260ms	remaining: 1.11s
# 190:	learn: 0.5865252	total: 262ms	remaining: 1.11s
# 191:	learn: 0.5863490	total: 263ms	remaining: 1.1s
# 192:	learn: 0.5861911	total: 264ms	remaining: 1.1s
# 193:	learn: 0.5859570	total: 265ms	remaining: 1.1s
# 194:	learn: 0.5858126	total: 266ms	remaining: 1.1s
# 195:	learn: 0.5857254	total: 267ms	remaining: 1.09s
# 196:	learn: 0.5855872	total: 268ms	remaining: 1.09s
# 197:	learn: 0.5853687	total: 269ms	remaining: 1.09s
# 198:	learn: 0.5851831	total: 270ms	remaining: 1.09s
# 199:	learn: 0.5850307	total: 271ms	remaining: 1.08s
# 200:	learn: 0.5848297	total: 273ms	remaining: 1.08s
# 201:	learn: 0.5846785	total: 274ms	remaining: 1.08s
# 202:	learn: 0.5845938	total: 275ms	remaining: 1.08s
# 203:	learn: 0.5843221	total: 276ms	remaining: 1.08s
# 204:	learn: 0.5841753	total: 277ms	remaining: 1.07s
# 205:	learn: 0.5839714	total: 278ms	remaining: 1.07s
# 206:	learn: 0.5837554	total: 280ms	remaining: 1.07s
# 207:	learn: 0.5836042	total: 281ms	remaining: 1.07s
# 208:	learn: 0.5833674	total: 282ms	remaining: 1.07s
# 209:	learn: 0.5831307	total: 283ms	remaining: 1.07s
# 210:	learn: 0.5830110	total: 285ms	remaining: 1.06s
# 211:	learn: 0.5828811	total: 286ms	remaining: 1.06s
# 212:	learn: 0.5827652	total: 287ms	remaining: 1.06s
# 213:	learn: 0.5826238	total: 289ms	remaining: 1.06s
# 214:	learn: 0.5823395	total: 290ms	remaining: 1.06s
# 215:	learn: 0.5820641	total: 291ms	remaining: 1.06s
# 216:	learn: 0.5818360	total: 292ms	remaining: 1.05s
# 217:	learn: 0.5816705	total: 293ms	remaining: 1.05s
# 218:	learn: 0.5814373	total: 295ms	remaining: 1.05s
# 219:	learn: 0.5811888	total: 296ms	remaining: 1.05s
# 220:	learn: 0.5809428	total: 297ms	remaining: 1.05s
# 221:	learn: 0.5807944	total: 298ms	remaining: 1.04s
# 222:	learn: 0.5805887	total: 300ms	remaining: 1.04s
# 223:	learn: 0.5803915	total: 301ms	remaining: 1.04s
# 224:	learn: 0.5803481	total: 302ms	remaining: 1.04s
# 225:	learn: 0.5801158	total: 303ms	remaining: 1.04s
# 226:	learn: 0.5799417	total: 304ms	remaining: 1.03s
# 227:	learn: 0.5797805	total: 305ms	remaining: 1.03s
# 228:	learn: 0.5795679	total: 306ms	remaining: 1.03s
# 229:	learn: 0.5793696	total: 307ms	remaining: 1.03s
# 230:	learn: 0.5791250	total: 308ms	remaining: 1.03s
# 231:	learn: 0.5789385	total: 309ms	remaining: 1.02s
# 232:	learn: 0.5787235	total: 310ms	remaining: 1.02s
# 233:	learn: 0.5784789	total: 312ms	remaining: 1.02s
# 234:	learn: 0.5782800	total: 313ms	remaining: 1.02s
# 235:	learn: 0.5781019	total: 314ms	remaining: 1.01s
# 236:	learn: 0.5779070	total: 315ms	remaining: 1.01s
# 237:	learn: 0.5777244	total: 316ms	remaining: 1.01s
# 238:	learn: 0.5775607	total: 317ms	remaining: 1.01s
# 239:	learn: 0.5774442	total: 318ms	remaining: 1.01s
# 240:	learn: 0.5772696	total: 320ms	remaining: 1.01s
# 241:	learn: 0.5771977	total: 321ms	remaining: 1s
# 242:	learn: 0.5769962	total: 322ms	remaining: 1s
# 243:	learn: 0.5769162	total: 323ms	remaining: 1s
# 244:	learn: 0.5767464	total: 324ms	remaining: 1000ms
# 245:	learn: 0.5764953	total: 326ms	remaining: 998ms
# 246:	learn: 0.5762876	total: 327ms	remaining: 996ms
# 247:	learn: 0.5761252	total: 328ms	remaining: 994ms
# 248:	learn: 0.5760327	total: 329ms	remaining: 992ms
# 249:	learn: 0.5758880	total: 330ms	remaining: 990ms
# 250:	learn: 0.5757399	total: 331ms	remaining: 988ms
# 251:	learn: 0.5755293	total: 332ms	remaining: 986ms
# 252:	learn: 0.5754000	total: 334ms	remaining: 985ms
# 253:	learn: 0.5751631	total: 335ms	remaining: 983ms
# 254:	learn: 0.5749514	total: 336ms	remaining: 982ms
# 255:	learn: 0.5747568	total: 337ms	remaining: 980ms
# 256:	learn: 0.5745374	total: 338ms	remaining: 978ms
# 257:	learn: 0.5743531	total: 339ms	remaining: 976ms
# 258:	learn: 0.5742616	total: 340ms	remaining: 974ms
# 259:	learn: 0.5741363	total: 341ms	remaining: 972ms
# 260:	learn: 0.5739762	total: 343ms	remaining: 970ms
# 261:	learn: 0.5738360	total: 344ms	remaining: 968ms
# 262:	learn: 0.5736253	total: 345ms	remaining: 968ms
# 263:	learn: 0.5734913	total: 346ms	remaining: 966ms
# 264:	learn: 0.5733137	total: 348ms	remaining: 964ms
# 265:	learn: 0.5731428	total: 349ms	remaining: 962ms
# 266:	learn: 0.5729529	total: 350ms	remaining: 960ms
# 267:	learn: 0.5727821	total: 351ms	remaining: 958ms
# 268:	learn: 0.5725682	total: 352ms	remaining: 956ms
# 269:	learn: 0.5723038	total: 353ms	remaining: 955ms
# 270:	learn: 0.5720287	total: 354ms	remaining: 953ms
# 271:	learn: 0.5719520	total: 356ms	remaining: 952ms
# 272:	learn: 0.5718224	total: 357ms	remaining: 950ms
# 273:	learn: 0.5715889	total: 358ms	remaining: 948ms
# 274:	learn: 0.5713952	total: 359ms	remaining: 946ms
# 275:	learn: 0.5713046	total: 360ms	remaining: 945ms
# 276:	learn: 0.5712069	total: 361ms	remaining: 943ms
# 277:	learn: 0.5710273	total: 362ms	remaining: 941ms
# 278:	learn: 0.5708898	total: 363ms	remaining: 939ms
# 279:	learn: 0.5706684	total: 364ms	remaining: 937ms
# 280:	learn: 0.5704854	total: 366ms	remaining: 935ms
# 281:	learn: 0.5703053	total: 367ms	remaining: 934ms
# 282:	learn: 0.5701831	total: 368ms	remaining: 932ms
# 283:	learn: 0.5699501	total: 369ms	remaining: 930ms
# 284:	learn: 0.5698408	total: 370ms	remaining: 928ms
# 285:	learn: 0.5696257	total: 371ms	remaining: 927ms
# 286:	learn: 0.5694686	total: 372ms	remaining: 925ms
# 287:	learn: 0.5693295	total: 373ms	remaining: 923ms
# 288:	learn: 0.5692532	total: 374ms	remaining: 921ms
# 289:	learn: 0.5690805	total: 376ms	remaining: 919ms
# 290:	learn: 0.5688887	total: 377ms	remaining: 918ms
# 291:	learn: 0.5686790	total: 378ms	remaining: 916ms
# 292:	learn: 0.5684719	total: 379ms	remaining: 914ms
# 293:	learn: 0.5682409	total: 380ms	remaining: 913ms
# 294:	learn: 0.5680661	total: 381ms	remaining: 912ms
# 295:	learn: 0.5678637	total: 383ms	remaining: 911ms
# 296:	learn: 0.5676628	total: 384ms	remaining: 909ms
# 297:	learn: 0.5674080	total: 386ms	remaining: 908ms
# 298:	learn: 0.5672640	total: 387ms	remaining: 908ms
# 299:	learn: 0.5671218	total: 389ms	remaining: 908ms
# 300:	learn: 0.5669627	total: 390ms	remaining: 906ms
# 301:	learn: 0.5667579	total: 391ms	remaining: 905ms
# 302:	learn: 0.5666362	total: 392ms	remaining: 903ms
# 303:	learn: 0.5664946	total: 394ms	remaining: 901ms
# 304:	learn: 0.5663051	total: 395ms	remaining: 900ms
# 305:	learn: 0.5662068	total: 396ms	remaining: 898ms
# 306:	learn: 0.5658983	total: 397ms	remaining: 897ms
# 307:	learn: 0.5656140	total: 399ms	remaining: 896ms
# 308:	learn: 0.5654697	total: 400ms	remaining: 895ms
# 309:	learn: 0.5653250	total: 402ms	remaining: 894ms
# 310:	learn: 0.5651466	total: 403ms	remaining: 892ms
# 311:	learn: 0.5650471	total: 404ms	remaining: 891ms
# 312:	learn: 0.5648334	total: 405ms	remaining: 890ms
# 313:	learn: 0.5647235	total: 406ms	remaining: 888ms
# 314:	learn: 0.5645429	total: 408ms	remaining: 887ms
# 315:	learn: 0.5642983	total: 409ms	remaining: 885ms
# 316:	learn: 0.5641493	total: 410ms	remaining: 883ms
# 317:	learn: 0.5640419	total: 412ms	remaining: 883ms
# 318:	learn: 0.5638499	total: 413ms	remaining: 881ms
# 319:	learn: 0.5636914	total: 414ms	remaining: 880ms
# 320:	learn: 0.5635667	total: 415ms	remaining: 878ms
# 321:	learn: 0.5634957	total: 416ms	remaining: 877ms
# 322:	learn: 0.5632420	total: 418ms	remaining: 876ms
# 323:	learn: 0.5630385	total: 420ms	remaining: 875ms
# 324:	learn: 0.5629076	total: 421ms	remaining: 874ms
# 325:	learn: 0.5628122	total: 422ms	remaining: 873ms
# 326:	learn: 0.5625698	total: 424ms	remaining: 872ms
# 327:	learn: 0.5624198	total: 425ms	remaining: 870ms
# 328:	learn: 0.5622624	total: 426ms	remaining: 868ms
# 329:	learn: 0.5621068	total: 427ms	remaining: 867ms
# 330:	learn: 0.5619388	total: 428ms	remaining: 865ms
# 331:	learn: 0.5616939	total: 429ms	remaining: 864ms
# 332:	learn: 0.5614398	total: 430ms	remaining: 862ms
# 333:	learn: 0.5612030	total: 431ms	remaining: 860ms
# 334:	learn: 0.5610374	total: 433ms	remaining: 859ms
# 335:	learn: 0.5608304	total: 434ms	remaining: 857ms
# 336:	learn: 0.5606262	total: 435ms	remaining: 856ms
# 337:	learn: 0.5604790	total: 436ms	remaining: 854ms
# 338:	learn: 0.5603130	total: 438ms	remaining: 853ms
# 339:	learn: 0.5600575	total: 439ms	remaining: 852ms
# 340:	learn: 0.5600048	total: 440ms	remaining: 850ms
# 341:	learn: 0.5598060	total: 441ms	remaining: 848ms
# 342:	learn: 0.5597372	total: 442ms	remaining: 847ms
# 343:	learn: 0.5596304	total: 443ms	remaining: 845ms
# 344:	learn: 0.5595218	total: 444ms	remaining: 844ms
# 345:	learn: 0.5593499	total: 446ms	remaining: 842ms
# 346:	learn: 0.5592167	total: 447ms	remaining: 841ms
# 347:	learn: 0.5591233	total: 448ms	remaining: 839ms
# 348:	learn: 0.5589646	total: 449ms	remaining: 837ms
# 349:	learn: 0.5588001	total: 450ms	remaining: 836ms
# 350:	learn: 0.5586214	total: 451ms	remaining: 834ms
# 351:	learn: 0.5585358	total: 452ms	remaining: 832ms
# 352:	learn: 0.5583602	total: 453ms	remaining: 831ms
# 353:	learn: 0.5582002	total: 454ms	remaining: 829ms
# 354:	learn: 0.5579802	total: 456ms	remaining: 828ms
# 355:	learn: 0.5578020	total: 457ms	remaining: 826ms
# 356:	learn: 0.5576281	total: 458ms	remaining: 825ms
# 357:	learn: 0.5574582	total: 459ms	remaining: 823ms
# 358:	learn: 0.5572315	total: 460ms	remaining: 821ms
# 359:	learn: 0.5571021	total: 461ms	remaining: 820ms
# 360:	learn: 0.5568979	total: 462ms	remaining: 818ms
# 361:	learn: 0.5567103	total: 464ms	remaining: 817ms
# 362:	learn: 0.5565404	total: 465ms	remaining: 816ms
# 363:	learn: 0.5563502	total: 466ms	remaining: 815ms
# 364:	learn: 0.5561632	total: 468ms	remaining: 813ms
# 365:	learn: 0.5559269	total: 469ms	remaining: 812ms
# 366:	learn: 0.5556877	total: 470ms	remaining: 810ms
# 367:	learn: 0.5555136	total: 471ms	remaining: 809ms
# 368:	learn: 0.5553339	total: 472ms	remaining: 807ms
# 369:	learn: 0.5551800	total: 473ms	remaining: 806ms
# 370:	learn: 0.5550031	total: 475ms	remaining: 805ms
# 371:	learn: 0.5548668	total: 476ms	remaining: 803ms
# 372:	learn: 0.5545750	total: 477ms	remaining: 801ms
# 373:	learn: 0.5543864	total: 478ms	remaining: 800ms
# 374:	learn: 0.5542428	total: 479ms	remaining: 798ms
# 375:	learn: 0.5541384	total: 480ms	remaining: 797ms
# 376:	learn: 0.5539001	total: 481ms	remaining: 795ms
# 377:	learn: 0.5537608	total: 482ms	remaining: 794ms
# 378:	learn: 0.5535745	total: 484ms	remaining: 792ms
# 379:	learn: 0.5533854	total: 485ms	remaining: 791ms
# 380:	learn: 0.5532319	total: 486ms	remaining: 789ms
# 381:	learn: 0.5530608	total: 487ms	remaining: 788ms
# 382:	learn: 0.5528571	total: 488ms	remaining: 786ms
# 383:	learn: 0.5527624	total: 489ms	remaining: 784ms
# 384:	learn: 0.5526593	total: 490ms	remaining: 783ms
# 385:	learn: 0.5524540	total: 491ms	remaining: 781ms
# 386:	learn: 0.5522624	total: 492ms	remaining: 779ms
# 387:	learn: 0.5521660	total: 493ms	remaining: 778ms
# 388:	learn: 0.5519607	total: 494ms	remaining: 776ms
# 389:	learn: 0.5518198	total: 495ms	remaining: 775ms
# 390:	learn: 0.5516399	total: 497ms	remaining: 773ms
# 391:	learn: 0.5515387	total: 498ms	remaining: 772ms
# 392:	learn: 0.5513988	total: 499ms	remaining: 771ms
# 393:	learn: 0.5511593	total: 500ms	remaining: 769ms
# 394:	learn: 0.5510138	total: 501ms	remaining: 768ms
# 395:	learn: 0.5508230	total: 503ms	remaining: 767ms
# 396:	learn: 0.5506462	total: 504ms	remaining: 765ms
# 397:	learn: 0.5504900	total: 505ms	remaining: 764ms
# 398:	learn: 0.5502921	total: 506ms	remaining: 762ms
# 399:	learn: 0.5501937	total: 507ms	remaining: 761ms
# 400:	learn: 0.5500852	total: 508ms	remaining: 759ms
# 401:	learn: 0.5498671	total: 509ms	remaining: 757ms
# 402:	learn: 0.5497843	total: 510ms	remaining: 756ms
# 403:	learn: 0.5495699	total: 511ms	remaining: 754ms
# 404:	learn: 0.5494508	total: 512ms	remaining: 753ms
# 405:	learn: 0.5492392	total: 514ms	remaining: 751ms
# 406:	learn: 0.5491248	total: 515ms	remaining: 750ms
# 407:	learn: 0.5489094	total: 516ms	remaining: 749ms
# 408:	learn: 0.5487379	total: 517ms	remaining: 747ms
# 409:	learn: 0.5484783	total: 518ms	remaining: 746ms
# 410:	learn: 0.5482533	total: 520ms	remaining: 745ms
# 411:	learn: 0.5480475	total: 521ms	remaining: 743ms
# 412:	learn: 0.5478593	total: 522ms	remaining: 742ms
# 413:	learn: 0.5477298	total: 523ms	remaining: 741ms
# 414:	learn: 0.5475883	total: 524ms	remaining: 739ms
# 415:	learn: 0.5474163	total: 526ms	remaining: 738ms
# 416:	learn: 0.5472237	total: 527ms	remaining: 736ms
# 417:	learn: 0.5470492	total: 528ms	remaining: 735ms
# 418:	learn: 0.5468812	total: 529ms	remaining: 734ms
# 419:	learn: 0.5467302	total: 530ms	remaining: 733ms
# 420:	learn: 0.5464999	total: 532ms	remaining: 731ms
# 421:	learn: 0.5463856	total: 533ms	remaining: 730ms
# 422:	learn: 0.5462180	total: 534ms	remaining: 728ms
# 423:	learn: 0.5459699	total: 535ms	remaining: 727ms
# 424:	learn: 0.5458071	total: 536ms	remaining: 725ms
# 425:	learn: 0.5456127	total: 537ms	remaining: 723ms
# 426:	learn: 0.5454120	total: 538ms	remaining: 722ms
# 427:	learn: 0.5451797	total: 539ms	remaining: 720ms
# 428:	learn: 0.5450391	total: 540ms	remaining: 719ms
# 429:	learn: 0.5448621	total: 541ms	remaining: 717ms
# 430:	learn: 0.5446222	total: 542ms	remaining: 716ms
# 431:	learn: 0.5444425	total: 544ms	remaining: 715ms
# 432:	learn: 0.5443680	total: 545ms	remaining: 713ms
# 433:	learn: 0.5442095	total: 546ms	remaining: 712ms
# 434:	learn: 0.5440703	total: 547ms	remaining: 711ms
# 435:	learn: 0.5439182	total: 548ms	remaining: 709ms
# 436:	learn: 0.5437027	total: 550ms	remaining: 708ms
# 437:	learn: 0.5434461	total: 551ms	remaining: 706ms
# 438:	learn: 0.5432233	total: 552ms	remaining: 705ms
# 439:	learn: 0.5430117	total: 553ms	remaining: 703ms
# 440:	learn: 0.5427995	total: 554ms	remaining: 702ms
# 441:	learn: 0.5426628	total: 555ms	remaining: 701ms
# 442:	learn: 0.5424248	total: 556ms	remaining: 699ms
# 443:	learn: 0.5423135	total: 558ms	remaining: 698ms
# 444:	learn: 0.5421484	total: 559ms	remaining: 697ms
# 445:	learn: 0.5419985	total: 560ms	remaining: 696ms
# 446:	learn: 0.5418293	total: 561ms	remaining: 694ms
# 447:	learn: 0.5416360	total: 562ms	remaining: 693ms
# 448:	learn: 0.5414881	total: 563ms	remaining: 692ms
# 449:	learn: 0.5413880	total: 565ms	remaining: 690ms
# 450:	learn: 0.5412670	total: 566ms	remaining: 689ms
# 451:	learn: 0.5411154	total: 567ms	remaining: 687ms
# 452:	learn: 0.5409034	total: 568ms	remaining: 686ms
# 453:	learn: 0.5406488	total: 569ms	remaining: 684ms
# 454:	learn: 0.5404090	total: 570ms	remaining: 683ms
# 455:	learn: 0.5403007	total: 571ms	remaining: 682ms
# 456:	learn: 0.5401535	total: 573ms	remaining: 680ms
# 457:	learn: 0.5399927	total: 574ms	remaining: 679ms
# 458:	learn: 0.5396972	total: 575ms	remaining: 678ms
# 459:	learn: 0.5394795	total: 576ms	remaining: 677ms
# 460:	learn: 0.5393298	total: 578ms	remaining: 676ms
# 461:	learn: 0.5390960	total: 579ms	remaining: 674ms
# 462:	learn: 0.5389235	total: 580ms	remaining: 673ms
# 463:	learn: 0.5387427	total: 581ms	remaining: 672ms
# 464:	learn: 0.5385643	total: 583ms	remaining: 670ms
# 465:	learn: 0.5383600	total: 584ms	remaining: 669ms
# 466:	learn: 0.5381348	total: 585ms	remaining: 667ms
# 467:	learn: 0.5379038	total: 586ms	remaining: 666ms
# 468:	learn: 0.5377617	total: 587ms	remaining: 664ms
# 469:	learn: 0.5376220	total: 588ms	remaining: 663ms
# 470:	learn: 0.5374461	total: 589ms	remaining: 662ms
# 471:	learn: 0.5372567	total: 590ms	remaining: 660ms
# 472:	learn: 0.5370580	total: 591ms	remaining: 659ms
# 473:	learn: 0.5368559	total: 592ms	remaining: 657ms
# 474:	learn: 0.5366562	total: 594ms	remaining: 656ms
# 475:	learn: 0.5364206	total: 595ms	remaining: 654ms
# 476:	learn: 0.5361993	total: 596ms	remaining: 653ms
# 477:	learn: 0.5360501	total: 597ms	remaining: 652ms
# 478:	learn: 0.5359309	total: 598ms	remaining: 650ms
# 479:	learn: 0.5357146	total: 599ms	remaining: 649ms
# 480:	learn: 0.5354463	total: 600ms	remaining: 648ms
# 481:	learn: 0.5352656	total: 602ms	remaining: 646ms
# 482:	learn: 0.5349938	total: 603ms	remaining: 645ms
# 483:	learn: 0.5348154	total: 604ms	remaining: 644ms
# 484:	learn: 0.5346356	total: 605ms	remaining: 642ms
# 485:	learn: 0.5344975	total: 606ms	remaining: 641ms
# 486:	learn: 0.5343562	total: 608ms	remaining: 640ms
# 487:	learn: 0.5341585	total: 609ms	remaining: 639ms
# 488:	learn: 0.5339377	total: 610ms	remaining: 637ms
# 489:	learn: 0.5337909	total: 611ms	remaining: 636ms
# 490:	learn: 0.5335513	total: 612ms	remaining: 635ms
# 491:	learn: 0.5334503	total: 614ms	remaining: 633ms
# 492:	learn: 0.5332471	total: 615ms	remaining: 632ms
# 493:	learn: 0.5331263	total: 616ms	remaining: 631ms
# 494:	learn: 0.5329516	total: 617ms	remaining: 630ms
# 495:	learn: 0.5328084	total: 618ms	remaining: 628ms
# 496:	learn: 0.5326012	total: 619ms	remaining: 627ms
# 497:	learn: 0.5322779	total: 620ms	remaining: 625ms
# 498:	learn: 0.5320277	total: 622ms	remaining: 624ms
# 499:	learn: 0.5318592	total: 623ms	remaining: 623ms
# 500:	learn: 0.5316320	total: 624ms	remaining: 622ms
# 501:	learn: 0.5314443	total: 625ms	remaining: 620ms
# 502:	learn: 0.5312788	total: 627ms	remaining: 619ms
# 503:	learn: 0.5311169	total: 628ms	remaining: 618ms
# 504:	learn: 0.5309016	total: 629ms	remaining: 617ms
# 505:	learn: 0.5306535	total: 630ms	remaining: 615ms
# 506:	learn: 0.5304996	total: 631ms	remaining: 614ms
# 507:	learn: 0.5302963	total: 632ms	remaining: 612ms
# 508:	learn: 0.5301051	total: 633ms	remaining: 611ms
# 509:	learn: 0.5299104	total: 634ms	remaining: 610ms
# 510:	learn: 0.5297313	total: 636ms	remaining: 608ms
# 511:	learn: 0.5295415	total: 637ms	remaining: 607ms
# 512:	learn: 0.5293579	total: 638ms	remaining: 605ms
# 513:	learn: 0.5292371	total: 639ms	remaining: 604ms
# 514:	learn: 0.5290538	total: 640ms	remaining: 603ms
# 515:	learn: 0.5288135	total: 641ms	remaining: 601ms
# 516:	learn: 0.5285343	total: 643ms	remaining: 601ms
# 517:	learn: 0.5283497	total: 644ms	remaining: 599ms
# 518:	learn: 0.5281474	total: 645ms	remaining: 598ms
# 519:	learn: 0.5280019	total: 646ms	remaining: 597ms
# 520:	learn: 0.5278100	total: 647ms	remaining: 595ms
# 521:	learn: 0.5276079	total: 648ms	remaining: 594ms
# 522:	learn: 0.5274175	total: 650ms	remaining: 593ms
# 523:	learn: 0.5271787	total: 651ms	remaining: 591ms
# 524:	learn: 0.5269813	total: 652ms	remaining: 590ms
# 525:	learn: 0.5267309	total: 653ms	remaining: 589ms
# 526:	learn: 0.5264875	total: 654ms	remaining: 587ms
# 527:	learn: 0.5263431	total: 656ms	remaining: 586ms
# 528:	learn: 0.5262366	total: 657ms	remaining: 585ms
# 529:	learn: 0.5260854	total: 658ms	remaining: 584ms
# 530:	learn: 0.5259286	total: 659ms	remaining: 582ms
# 531:	learn: 0.5256265	total: 661ms	remaining: 581ms
# 532:	learn: 0.5254697	total: 662ms	remaining: 580ms
# 533:	learn: 0.5252614	total: 663ms	remaining: 578ms
# 534:	learn: 0.5250715	total: 664ms	remaining: 577ms
# 535:	learn: 0.5249045	total: 665ms	remaining: 576ms
# 536:	learn: 0.5247781	total: 666ms	remaining: 574ms
# 537:	learn: 0.5246384	total: 667ms	remaining: 573ms
# 538:	learn: 0.5244014	total: 668ms	remaining: 572ms
# 539:	learn: 0.5242172	total: 669ms	remaining: 570ms
# 540:	learn: 0.5240638	total: 670ms	remaining: 569ms
# 541:	learn: 0.5238631	total: 672ms	remaining: 568ms
# 542:	learn: 0.5237550	total: 673ms	remaining: 566ms
# 543:	learn: 0.5235302	total: 674ms	remaining: 565ms
# 544:	learn: 0.5232903	total: 675ms	remaining: 564ms
# 545:	learn: 0.5229770	total: 676ms	remaining: 562ms
# 546:	learn: 0.5228348	total: 678ms	remaining: 561ms
# 547:	learn: 0.5226370	total: 679ms	remaining: 560ms
# 548:	learn: 0.5224122	total: 680ms	remaining: 558ms
# 549:	learn: 0.5220475	total: 681ms	remaining: 557ms
# 550:	learn: 0.5218901	total: 682ms	remaining: 556ms
# 551:	learn: 0.5217618	total: 683ms	remaining: 554ms
# 552:	learn: 0.5215906	total: 684ms	remaining: 553ms
# 553:	learn: 0.5214163	total: 686ms	remaining: 552ms
# 554:	learn: 0.5211417	total: 687ms	remaining: 551ms
# 555:	learn: 0.5209977	total: 688ms	remaining: 549ms
# 556:	learn: 0.5208676	total: 689ms	remaining: 548ms
# 557:	learn: 0.5206566	total: 690ms	remaining: 547ms
# 558:	learn: 0.5205011	total: 691ms	remaining: 545ms
# 559:	learn: 0.5203524	total: 692ms	remaining: 544ms
# 560:	learn: 0.5201613	total: 694ms	remaining: 543ms
# 561:	learn: 0.5200527	total: 695ms	remaining: 541ms
# 562:	learn: 0.5197831	total: 696ms	remaining: 540ms
# 563:	learn: 0.5196549	total: 697ms	remaining: 539ms
# 564:	learn: 0.5194857	total: 698ms	remaining: 537ms
# 565:	learn: 0.5193338	total: 699ms	remaining: 536ms
# 566:	learn: 0.5191220	total: 700ms	remaining: 535ms
# 567:	learn: 0.5189447	total: 702ms	remaining: 534ms
# 568:	learn: 0.5187749	total: 703ms	remaining: 532ms
# 569:	learn: 0.5186559	total: 704ms	remaining: 531ms
# 570:	learn: 0.5185115	total: 705ms	remaining: 530ms
# 571:	learn: 0.5183285	total: 706ms	remaining: 529ms
# 572:	learn: 0.5181538	total: 707ms	remaining: 527ms
# 573:	learn: 0.5179932	total: 709ms	remaining: 526ms
# 574:	learn: 0.5177576	total: 710ms	remaining: 525ms
# 575:	learn: 0.5175176	total: 711ms	remaining: 523ms
# 576:	learn: 0.5173835	total: 712ms	remaining: 522ms
# 577:	learn: 0.5171694	total: 713ms	remaining: 521ms
# 578:	learn: 0.5169753	total: 714ms	remaining: 519ms
# 579:	learn: 0.5167658	total: 715ms	remaining: 518ms
# 580:	learn: 0.5166061	total: 717ms	remaining: 517ms
# 581:	learn: 0.5163939	total: 718ms	remaining: 515ms
# 582:	learn: 0.5161988	total: 719ms	remaining: 514ms
# 583:	learn: 0.5159848	total: 720ms	remaining: 513ms
# 584:	learn: 0.5157380	total: 721ms	remaining: 512ms
# 585:	learn: 0.5155470	total: 722ms	remaining: 510ms
# 586:	learn: 0.5154007	total: 724ms	remaining: 509ms
# 587:	learn: 0.5152428	total: 725ms	remaining: 508ms
# 588:	learn: 0.5150750	total: 726ms	remaining: 506ms
# 589:	learn: 0.5149428	total: 727ms	remaining: 505ms
# 590:	learn: 0.5147504	total: 728ms	remaining: 504ms
# 591:	learn: 0.5145953	total: 729ms	remaining: 503ms
# 592:	learn: 0.5144285	total: 731ms	remaining: 501ms
# 593:	learn: 0.5142272	total: 732ms	remaining: 500ms
# 594:	learn: 0.5140420	total: 733ms	remaining: 499ms
# 595:	learn: 0.5139204	total: 734ms	remaining: 497ms
# 596:	learn: 0.5137602	total: 735ms	remaining: 496ms
# 597:	learn: 0.5135122	total: 736ms	remaining: 495ms
# 598:	learn: 0.5133798	total: 737ms	remaining: 494ms
# 599:	learn: 0.5131921	total: 739ms	remaining: 492ms
# 600:	learn: 0.5130297	total: 740ms	remaining: 491ms
# 601:	learn: 0.5129474	total: 741ms	remaining: 490ms
# 602:	learn: 0.5126972	total: 742ms	remaining: 488ms
# 603:	learn: 0.5124887	total: 743ms	remaining: 487ms
# 604:	learn: 0.5122834	total: 744ms	remaining: 486ms
# 605:	learn: 0.5120367	total: 745ms	remaining: 485ms
# 606:	learn: 0.5117864	total: 747ms	remaining: 484ms
# 607:	learn: 0.5116580	total: 748ms	remaining: 482ms
# 608:	learn: 0.5113990	total: 749ms	remaining: 481ms
# 609:	learn: 0.5112531	total: 750ms	remaining: 480ms
# 610:	learn: 0.5109987	total: 751ms	remaining: 478ms
# 611:	learn: 0.5107651	total: 752ms	remaining: 477ms
# 612:	learn: 0.5105678	total: 753ms	remaining: 476ms
# 613:	learn: 0.5103249	total: 754ms	remaining: 474ms
# 614:	learn: 0.5100884	total: 756ms	remaining: 473ms
# 615:	learn: 0.5098977	total: 757ms	remaining: 472ms
# 616:	learn: 0.5097340	total: 758ms	remaining: 470ms
# 617:	learn: 0.5095782	total: 759ms	remaining: 469ms
# 618:	learn: 0.5092622	total: 760ms	remaining: 468ms
# 619:	learn: 0.5091205	total: 761ms	remaining: 467ms
# 620:	learn: 0.5089229	total: 762ms	remaining: 465ms
# 621:	learn: 0.5086853	total: 764ms	remaining: 464ms
# 622:	learn: 0.5084470	total: 765ms	remaining: 463ms
# 623:	learn: 0.5082820	total: 766ms	remaining: 461ms
# 624:	learn: 0.5080843	total: 767ms	remaining: 460ms
# 625:	learn: 0.5078231	total: 768ms	remaining: 459ms
# 626:	learn: 0.5076401	total: 769ms	remaining: 458ms
# 627:	learn: 0.5073909	total: 771ms	remaining: 457ms
# 628:	learn: 0.5072419	total: 772ms	remaining: 455ms
# 629:	learn: 0.5071609	total: 773ms	remaining: 454ms
# 630:	learn: 0.5069815	total: 774ms	remaining: 453ms
# 631:	learn: 0.5068767	total: 775ms	remaining: 452ms
# 632:	learn: 0.5066876	total: 777ms	remaining: 450ms
# 633:	learn: 0.5064887	total: 778ms	remaining: 449ms
# 634:	learn: 0.5063107	total: 779ms	remaining: 448ms
# 635:	learn: 0.5061254	total: 780ms	remaining: 446ms
# 636:	learn: 0.5059616	total: 781ms	remaining: 445ms
# 637:	learn: 0.5057836	total: 782ms	remaining: 444ms
# 638:	learn: 0.5055678	total: 784ms	remaining: 443ms
# 639:	learn: 0.5053215	total: 785ms	remaining: 441ms
# 640:	learn: 0.5050894	total: 786ms	remaining: 440ms
# 641:	learn: 0.5049534	total: 787ms	remaining: 439ms
# 642:	learn: 0.5047209	total: 788ms	remaining: 438ms
# 643:	learn: 0.5045480	total: 790ms	remaining: 437ms
# 644:	learn: 0.5044347	total: 791ms	remaining: 435ms
# 645:	learn: 0.5042541	total: 792ms	remaining: 434ms
# 646:	learn: 0.5040538	total: 793ms	remaining: 433ms
# 647:	learn: 0.5039084	total: 794ms	remaining: 431ms
# 648:	learn: 0.5037737	total: 795ms	remaining: 430ms
# 649:	learn: 0.5036241	total: 797ms	remaining: 429ms
# 650:	learn: 0.5033801	total: 798ms	remaining: 428ms
# 651:	learn: 0.5032489	total: 799ms	remaining: 426ms
# 652:	learn: 0.5030927	total: 800ms	remaining: 425ms
# 653:	learn: 0.5030035	total: 801ms	remaining: 424ms
# 654:	learn: 0.5027949	total: 802ms	remaining: 422ms
# 655:	learn: 0.5026650	total: 803ms	remaining: 421ms
# 656:	learn: 0.5025032	total: 804ms	remaining: 420ms
# 657:	learn: 0.5022779	total: 805ms	remaining: 419ms
# 658:	learn: 0.5021204	total: 806ms	remaining: 417ms
# 659:	learn: 0.5019554	total: 808ms	remaining: 416ms
# 660:	learn: 0.5018359	total: 809ms	remaining: 415ms
# 661:	learn: 0.5016200	total: 810ms	remaining: 413ms
# 662:	learn: 0.5015288	total: 811ms	remaining: 412ms
# 663:	learn: 0.5013782	total: 812ms	remaining: 411ms
# 664:	learn: 0.5011767	total: 813ms	remaining: 410ms
# 665:	learn: 0.5010744	total: 815ms	remaining: 409ms
# 666:	learn: 0.5009509	total: 816ms	remaining: 407ms
# 667:	learn: 0.5007820	total: 817ms	remaining: 406ms
# 668:	learn: 0.5006250	total: 819ms	remaining: 405ms
# 669:	learn: 0.5004603	total: 820ms	remaining: 404ms
# 670:	learn: 0.5003128	total: 822ms	remaining: 403ms
# 671:	learn: 0.5002115	total: 823ms	remaining: 402ms
# 672:	learn: 0.4999938	total: 824ms	remaining: 400ms
# 673:	learn: 0.4998165	total: 825ms	remaining: 399ms
# 674:	learn: 0.4996591	total: 826ms	remaining: 398ms
# 675:	learn: 0.4995165	total: 827ms	remaining: 397ms
# 676:	learn: 0.4994293	total: 829ms	remaining: 395ms
# 677:	learn: 0.4992530	total: 830ms	remaining: 394ms
# 678:	learn: 0.4990785	total: 831ms	remaining: 393ms
# 679:	learn: 0.4988962	total: 832ms	remaining: 392ms
# 680:	learn: 0.4987350	total: 834ms	remaining: 390ms
# 681:	learn: 0.4985907	total: 835ms	remaining: 389ms
# 682:	learn: 0.4984323	total: 836ms	remaining: 388ms
# 683:	learn: 0.4981814	total: 837ms	remaining: 387ms
# 684:	learn: 0.4979013	total: 838ms	remaining: 386ms
# 685:	learn: 0.4976508	total: 840ms	remaining: 384ms
# 686:	learn: 0.4974996	total: 841ms	remaining: 383ms
# 687:	learn: 0.4974321	total: 843ms	remaining: 382ms
# 688:	learn: 0.4973313	total: 844ms	remaining: 381ms
# 689:	learn: 0.4972196	total: 845ms	remaining: 380ms
# 690:	learn: 0.4971280	total: 846ms	remaining: 378ms
# 691:	learn: 0.4969468	total: 847ms	remaining: 377ms
# 692:	learn: 0.4967536	total: 849ms	remaining: 376ms
# 693:	learn: 0.4966049	total: 850ms	remaining: 375ms
# 694:	learn: 0.4963990	total: 851ms	remaining: 373ms
# 695:	learn: 0.4962631	total: 852ms	remaining: 372ms
# 696:	learn: 0.4960559	total: 853ms	remaining: 371ms
# 697:	learn: 0.4958712	total: 854ms	remaining: 370ms
# 698:	learn: 0.4957322	total: 855ms	remaining: 368ms
# 699:	learn: 0.4955522	total: 857ms	remaining: 367ms
# 700:	learn: 0.4953361	total: 858ms	remaining: 366ms
# 701:	learn: 0.4950910	total: 859ms	remaining: 365ms
# 702:	learn: 0.4949029	total: 860ms	remaining: 363ms
# 703:	learn: 0.4946876	total: 862ms	remaining: 362ms
# 704:	learn: 0.4944731	total: 863ms	remaining: 361ms
# 705:	learn: 0.4943138	total: 864ms	remaining: 360ms
# 706:	learn: 0.4941368	total: 865ms	remaining: 358ms
# 707:	learn: 0.4939836	total: 866ms	remaining: 357ms
# 708:	learn: 0.4937872	total: 867ms	remaining: 356ms
# 709:	learn: 0.4936708	total: 868ms	remaining: 355ms
# 710:	learn: 0.4934522	total: 869ms	remaining: 353ms
# 711:	learn: 0.4932948	total: 870ms	remaining: 352ms
# 712:	learn: 0.4931804	total: 871ms	remaining: 351ms
# 713:	learn: 0.4929722	total: 873ms	remaining: 350ms
# 714:	learn: 0.4928309	total: 874ms	remaining: 348ms
# 715:	learn: 0.4926945	total: 875ms	remaining: 347ms
# 716:	learn: 0.4925756	total: 876ms	remaining: 346ms
# 717:	learn: 0.4924327	total: 877ms	remaining: 344ms
# 718:	learn: 0.4922074	total: 878ms	remaining: 343ms
# 719:	learn: 0.4919391	total: 879ms	remaining: 342ms
# 720:	learn: 0.4918037	total: 881ms	remaining: 341ms
# 721:	learn: 0.4915717	total: 882ms	remaining: 340ms
# 722:	learn: 0.4913709	total: 883ms	remaining: 338ms
# 723:	learn: 0.4912102	total: 884ms	remaining: 337ms
# 724:	learn: 0.4910011	total: 886ms	remaining: 336ms
# 725:	learn: 0.4908520	total: 887ms	remaining: 335ms
# 726:	learn: 0.4906458	total: 888ms	remaining: 333ms
# 727:	learn: 0.4904706	total: 889ms	remaining: 332ms
# 728:	learn: 0.4901803	total: 891ms	remaining: 331ms
# 729:	learn: 0.4900156	total: 892ms	remaining: 330ms
# 730:	learn: 0.4898247	total: 893ms	remaining: 329ms
# 731:	learn: 0.4896436	total: 894ms	remaining: 327ms
# 732:	learn: 0.4894908	total: 895ms	remaining: 326ms
# 733:	learn: 0.4893449	total: 897ms	remaining: 325ms
# 734:	learn: 0.4892251	total: 898ms	remaining: 324ms
# 735:	learn: 0.4890837	total: 900ms	remaining: 323ms
# 736:	learn: 0.4889225	total: 901ms	remaining: 322ms
# 737:	learn: 0.4888206	total: 903ms	remaining: 320ms
# 738:	learn: 0.4886298	total: 904ms	remaining: 319ms
# 739:	learn: 0.4884854	total: 905ms	remaining: 318ms
# 740:	learn: 0.4883179	total: 906ms	remaining: 317ms
# 741:	learn: 0.4881865	total: 907ms	remaining: 315ms
# 742:	learn: 0.4879651	total: 908ms	remaining: 314ms
# 743:	learn: 0.4878476	total: 909ms	remaining: 313ms
# 744:	learn: 0.4876946	total: 910ms	remaining: 312ms
# 745:	learn: 0.4875915	total: 911ms	remaining: 310ms
# 746:	learn: 0.4874171	total: 913ms	remaining: 309ms
# 747:	learn: 0.4872598	total: 914ms	remaining: 308ms
# 748:	learn: 0.4871370	total: 915ms	remaining: 307ms
# 749:	learn: 0.4869232	total: 916ms	remaining: 305ms
# 750:	learn: 0.4868133	total: 917ms	remaining: 304ms
# 751:	learn: 0.4867152	total: 918ms	remaining: 303ms
# 752:	learn: 0.4865134	total: 919ms	remaining: 302ms
# 753:	learn: 0.4864198	total: 920ms	remaining: 300ms
# 754:	learn: 0.4861324	total: 922ms	remaining: 299ms
# 755:	learn: 0.4859272	total: 923ms	remaining: 298ms
# 756:	learn: 0.4857210	total: 924ms	remaining: 297ms
# 757:	learn: 0.4856233	total: 925ms	remaining: 295ms
# 758:	learn: 0.4855338	total: 927ms	remaining: 294ms
# 759:	learn: 0.4854416	total: 928ms	remaining: 293ms
# 760:	learn: 0.4852520	total: 929ms	remaining: 292ms
# 761:	learn: 0.4851408	total: 931ms	remaining: 291ms
# 762:	learn: 0.4849999	total: 932ms	remaining: 290ms
# 763:	learn: 0.4848295	total: 933ms	remaining: 288ms
# 764:	learn: 0.4846914	total: 934ms	remaining: 287ms
# 765:	learn: 0.4844891	total: 936ms	remaining: 286ms
# 766:	learn: 0.4843267	total: 937ms	remaining: 285ms
# 767:	learn: 0.4842376	total: 938ms	remaining: 283ms
# 768:	learn: 0.4841531	total: 939ms	remaining: 282ms
# 769:	learn: 0.4840203	total: 940ms	remaining: 281ms
# 770:	learn: 0.4838382	total: 941ms	remaining: 280ms
# 771:	learn: 0.4837420	total: 942ms	remaining: 278ms
# 772:	learn: 0.4835831	total: 944ms	remaining: 277ms
# 773:	learn: 0.4835028	total: 945ms	remaining: 276ms
# 774:	learn: 0.4832692	total: 946ms	remaining: 275ms
# 775:	learn: 0.4830343	total: 947ms	remaining: 273ms
# 776:	learn: 0.4828897	total: 948ms	remaining: 272ms
# 777:	learn: 0.4827451	total: 949ms	remaining: 271ms
# 778:	learn: 0.4825122	total: 950ms	remaining: 270ms
# 779:	learn: 0.4823632	total: 952ms	remaining: 268ms
# 780:	learn: 0.4821592	total: 953ms	remaining: 267ms
# 781:	learn: 0.4820133	total: 954ms	remaining: 266ms
# 782:	learn: 0.4819069	total: 955ms	remaining: 265ms
# 783:	learn: 0.4817922	total: 956ms	remaining: 263ms
# 784:	learn: 0.4817045	total: 957ms	remaining: 262ms
# 785:	learn: 0.4815742	total: 958ms	remaining: 261ms
# 786:	learn: 0.4814442	total: 960ms	remaining: 260ms
# 787:	learn: 0.4812708	total: 961ms	remaining: 258ms
# 788:	learn: 0.4811706	total: 962ms	remaining: 257ms
# 789:	learn: 0.4811073	total: 963ms	remaining: 256ms
# 790:	learn: 0.4809341	total: 964ms	remaining: 255ms
# 791:	learn: 0.4808393	total: 966ms	remaining: 254ms
# 792:	learn: 0.4807074	total: 967ms	remaining: 252ms
# 793:	learn: 0.4804804	total: 968ms	remaining: 251ms
# 794:	learn: 0.4803249	total: 969ms	remaining: 250ms
# 795:	learn: 0.4801746	total: 970ms	remaining: 249ms
# 796:	learn: 0.4799328	total: 971ms	remaining: 247ms
# 797:	learn: 0.4797824	total: 972ms	remaining: 246ms
# 798:	learn: 0.4796689	total: 973ms	remaining: 245ms
# 799:	learn: 0.4795812	total: 975ms	remaining: 244ms
# 800:	learn: 0.4794097	total: 976ms	remaining: 243ms
# 801:	learn: 0.4792383	total: 977ms	remaining: 241ms
# 802:	learn: 0.4790709	total: 979ms	remaining: 240ms
# 803:	learn: 0.4789016	total: 980ms	remaining: 239ms
# 804:	learn: 0.4787155	total: 981ms	remaining: 238ms
# 805:	learn: 0.4785423	total: 982ms	remaining: 236ms
# 806:	learn: 0.4783669	total: 983ms	remaining: 235ms
# 807:	learn: 0.4782133	total: 985ms	remaining: 234ms
# 808:	learn: 0.4779661	total: 986ms	remaining: 233ms
# 809:	learn: 0.4777632	total: 987ms	remaining: 232ms
# 810:	learn: 0.4775635	total: 989ms	remaining: 230ms
# 811:	learn: 0.4774547	total: 990ms	remaining: 229ms
# 812:	learn: 0.4772763	total: 991ms	remaining: 228ms
# 813:	learn: 0.4771248	total: 992ms	remaining: 227ms
# 814:	learn: 0.4770399	total: 993ms	remaining: 225ms
# 815:	learn: 0.4769432	total: 995ms	remaining: 224ms
# 816:	learn: 0.4767409	total: 996ms	remaining: 223ms
# 817:	learn: 0.4765802	total: 997ms	remaining: 222ms
# 818:	learn: 0.4763662	total: 998ms	remaining: 221ms
# 819:	learn: 0.4761945	total: 999ms	remaining: 219ms
# 820:	learn: 0.4761085	total: 1s	remaining: 218ms
# 821:	learn: 0.4759429	total: 1s	remaining: 217ms
# 822:	learn: 0.4758523	total: 1s	remaining: 216ms
# 823:	learn: 0.4757160	total: 1s	remaining: 214ms
# 824:	learn: 0.4755355	total: 1s	remaining: 213ms
# 825:	learn: 0.4754139	total: 1.01s	remaining: 212ms
# 826:	learn: 0.4753006	total: 1.01s	remaining: 211ms
# 827:	learn: 0.4751084	total: 1.01s	remaining: 210ms
# 828:	learn: 0.4749412	total: 1.01s	remaining: 208ms
# 829:	learn: 0.4748402	total: 1.01s	remaining: 207ms
# 830:	learn: 0.4747846	total: 1.01s	remaining: 206ms
# 831:	learn: 0.4746383	total: 1.01s	remaining: 205ms
# 832:	learn: 0.4745341	total: 1.01s	remaining: 204ms
# 833:	learn: 0.4743518	total: 1.02s	remaining: 202ms
# 834:	learn: 0.4742350	total: 1.02s	remaining: 201ms
# 835:	learn: 0.4740582	total: 1.02s	remaining: 200ms
# 836:	learn: 0.4738372	total: 1.02s	remaining: 199ms
# 837:	learn: 0.4736159	total: 1.02s	remaining: 197ms
# 838:	learn: 0.4734078	total: 1.02s	remaining: 196ms
# 839:	learn: 0.4733322	total: 1.02s	remaining: 195ms
# 840:	learn: 0.4732564	total: 1.02s	remaining: 194ms
# 841:	learn: 0.4731561	total: 1.02s	remaining: 192ms
# 842:	learn: 0.4729448	total: 1.03s	remaining: 191ms
# 843:	learn: 0.4728282	total: 1.03s	remaining: 190ms
# 844:	learn: 0.4726272	total: 1.03s	remaining: 189ms
# 845:	learn: 0.4725066	total: 1.03s	remaining: 188ms
# 846:	learn: 0.4723431	total: 1.03s	remaining: 186ms
# 847:	learn: 0.4722470	total: 1.03s	remaining: 185ms
# 848:	learn: 0.4721616	total: 1.03s	remaining: 184ms
# 849:	learn: 0.4720064	total: 1.03s	remaining: 183ms
# 850:	learn: 0.4718534	total: 1.04s	remaining: 182ms
# 851:	learn: 0.4715920	total: 1.04s	remaining: 180ms
# 852:	learn: 0.4714405	total: 1.04s	remaining: 179ms
# 853:	learn: 0.4713488	total: 1.04s	remaining: 178ms
# 854:	learn: 0.4711442	total: 1.04s	remaining: 177ms
# 855:	learn: 0.4710660	total: 1.04s	remaining: 175ms
# 856:	learn: 0.4709716	total: 1.04s	remaining: 174ms
# 857:	learn: 0.4708615	total: 1.04s	remaining: 173ms
# 858:	learn: 0.4707417	total: 1.05s	remaining: 172ms
# 859:	learn: 0.4706949	total: 1.05s	remaining: 170ms
# 860:	learn: 0.4706015	total: 1.05s	remaining: 169ms
# 861:	learn: 0.4704965	total: 1.05s	remaining: 168ms
# 862:	learn: 0.4703954	total: 1.05s	remaining: 167ms
# 863:	learn: 0.4702809	total: 1.05s	remaining: 166ms
# 864:	learn: 0.4701169	total: 1.05s	remaining: 164ms
# 865:	learn: 0.4699553	total: 1.05s	remaining: 163ms
# 866:	learn: 0.4697548	total: 1.05s	remaining: 162ms
# 867:	learn: 0.4695772	total: 1.06s	remaining: 161ms
# 868:	learn: 0.4693992	total: 1.06s	remaining: 159ms
# 869:	learn: 0.4692622	total: 1.06s	remaining: 158ms
# 870:	learn: 0.4691039	total: 1.06s	remaining: 157ms
# 871:	learn: 0.4689735	total: 1.06s	remaining: 156ms
# 872:	learn: 0.4688693	total: 1.06s	remaining: 154ms
# 873:	learn: 0.4687443	total: 1.06s	remaining: 153ms
# 874:	learn: 0.4686219	total: 1.06s	remaining: 152ms
# 875:	learn: 0.4684675	total: 1.06s	remaining: 151ms
# 876:	learn: 0.4683335	total: 1.07s	remaining: 150ms
# 877:	learn: 0.4682509	total: 1.07s	remaining: 148ms
# 878:	learn: 0.4680954	total: 1.07s	remaining: 147ms
# 879:	learn: 0.4680132	total: 1.07s	remaining: 146ms
# 880:	learn: 0.4679276	total: 1.07s	remaining: 145ms
# 881:	learn: 0.4677554	total: 1.07s	remaining: 143ms
# 882:	learn: 0.4676241	total: 1.07s	remaining: 142ms
# 883:	learn: 0.4674145	total: 1.07s	remaining: 141ms
# 884:	learn: 0.4673076	total: 1.07s	remaining: 140ms
# 885:	learn: 0.4671849	total: 1.08s	remaining: 139ms
# 886:	learn: 0.4670831	total: 1.08s	remaining: 137ms
# 887:	learn: 0.4669238	total: 1.08s	remaining: 136ms
# 888:	learn: 0.4667214	total: 1.08s	remaining: 135ms
# 889:	learn: 0.4665810	total: 1.08s	remaining: 134ms
# 890:	learn: 0.4664995	total: 1.08s	remaining: 132ms
# 891:	learn: 0.4662653	total: 1.08s	remaining: 131ms
# 892:	learn: 0.4661154	total: 1.08s	remaining: 130ms
# 893:	learn: 0.4660097	total: 1.08s	remaining: 129ms
# 894:	learn: 0.4658092	total: 1.09s	remaining: 128ms
# 895:	learn: 0.4657186	total: 1.09s	remaining: 126ms
# 896:	learn: 0.4655230	total: 1.09s	remaining: 125ms
# 897:	learn: 0.4654408	total: 1.09s	remaining: 124ms
# 898:	learn: 0.4653411	total: 1.09s	remaining: 123ms
# 899:	learn: 0.4652040	total: 1.09s	remaining: 121ms
# 900:	learn: 0.4650738	total: 1.09s	remaining: 120ms
# 901:	learn: 0.4648877	total: 1.09s	remaining: 119ms
# 902:	learn: 0.4647323	total: 1.1s	remaining: 118ms
# 903:	learn: 0.4645691	total: 1.1s	remaining: 117ms
# 904:	learn: 0.4644243	total: 1.1s	remaining: 115ms
# 905:	learn: 0.4643200	total: 1.1s	remaining: 114ms
# 906:	learn: 0.4641541	total: 1.1s	remaining: 113ms
# 907:	learn: 0.4640249	total: 1.1s	remaining: 112ms
# 908:	learn: 0.4639088	total: 1.1s	remaining: 110ms
# 909:	learn: 0.4638251	total: 1.1s	remaining: 109ms
# 910:	learn: 0.4636724	total: 1.1s	remaining: 108ms
# 911:	learn: 0.4635256	total: 1.11s	remaining: 107ms
# 912:	learn: 0.4633815	total: 1.11s	remaining: 106ms
# 913:	learn: 0.4631989	total: 1.11s	remaining: 104ms
# 914:	learn: 0.4630842	total: 1.11s	remaining: 103ms
# 915:	learn: 0.4630042	total: 1.11s	remaining: 102ms
# 916:	learn: 0.4628618	total: 1.11s	remaining: 101ms
# 917:	learn: 0.4627470	total: 1.11s	remaining: 99.5ms
# 918:	learn: 0.4626226	total: 1.11s	remaining: 98.3ms
# 919:	learn: 0.4624331	total: 1.12s	remaining: 97.1ms
# 920:	learn: 0.4623024	total: 1.12s	remaining: 95.9ms
# 921:	learn: 0.4622066	total: 1.12s	remaining: 94.7ms
# 922:	learn: 0.4620949	total: 1.12s	remaining: 93.4ms
# 923:	learn: 0.4619372	total: 1.12s	remaining: 92.2ms
# 924:	learn: 0.4618296	total: 1.12s	remaining: 91ms
# 925:	learn: 0.4615647	total: 1.12s	remaining: 89.8ms
# 926:	learn: 0.4613912	total: 1.12s	remaining: 88.5ms
# 927:	learn: 0.4613090	total: 1.13s	remaining: 87.3ms
# 928:	learn: 0.4611876	total: 1.13s	remaining: 86.1ms
# 929:	learn: 0.4610403	total: 1.13s	remaining: 84.9ms
# 930:	learn: 0.4609175	total: 1.13s	remaining: 83.6ms
# 931:	learn: 0.4607892	total: 1.13s	remaining: 82.4ms
# 932:	learn: 0.4606690	total: 1.13s	remaining: 81.2ms
# 933:	learn: 0.4605409	total: 1.13s	remaining: 80ms
# 934:	learn: 0.4604063	total: 1.13s	remaining: 78.8ms
# 935:	learn: 0.4602240	total: 1.13s	remaining: 77.6ms
# 936:	learn: 0.4600848	total: 1.14s	remaining: 76.4ms
# 937:	learn: 0.4599871	total: 1.14s	remaining: 75.1ms
# 938:	learn: 0.4598355	total: 1.14s	remaining: 73.9ms
# 939:	learn: 0.4596384	total: 1.14s	remaining: 72.7ms
# 940:	learn: 0.4595702	total: 1.14s	remaining: 71.5ms
# 941:	learn: 0.4594323	total: 1.14s	remaining: 70.3ms
# 942:	learn: 0.4592935	total: 1.14s	remaining: 69.1ms
# 943:	learn: 0.4591444	total: 1.14s	remaining: 67.8ms
# 944:	learn: 0.4590014	total: 1.14s	remaining: 66.6ms
# 945:	learn: 0.4589024	total: 1.15s	remaining: 65.4ms
# 946:	learn: 0.4587853	total: 1.15s	remaining: 64.2ms
# 947:	learn: 0.4587200	total: 1.15s	remaining: 63ms
# 948:	learn: 0.4585898	total: 1.15s	remaining: 61.8ms
# 949:	learn: 0.4584620	total: 1.15s	remaining: 60.5ms
# 950:	learn: 0.4583567	total: 1.15s	remaining: 59.3ms
# 951:	learn: 0.4582682	total: 1.15s	remaining: 58.1ms
# 952:	learn: 0.4581333	total: 1.15s	remaining: 56.9ms
# 953:	learn: 0.4580318	total: 1.16s	remaining: 55.7ms
# 954:	learn: 0.4579094	total: 1.16s	remaining: 54.5ms
# 955:	learn: 0.4578127	total: 1.16s	remaining: 53.3ms
# 956:	learn: 0.4577429	total: 1.16s	remaining: 52.1ms
# 957:	learn: 0.4575937	total: 1.16s	remaining: 50.9ms
# 958:	learn: 0.4574129	total: 1.16s	remaining: 49.7ms
# 959:	learn: 0.4572598	total: 1.16s	remaining: 48.5ms
# 960:	learn: 0.4570958	total: 1.16s	remaining: 47.2ms
# 961:	learn: 0.4569330	total: 1.17s	remaining: 46ms
# 962:	learn: 0.4568401	total: 1.17s	remaining: 44.8ms
# 963:	learn: 0.4566119	total: 1.17s	remaining: 43.6ms
# 964:	learn: 0.4564743	total: 1.17s	remaining: 42.4ms
# 965:	learn: 0.4563167	total: 1.17s	remaining: 41.2ms
# 966:	learn: 0.4560849	total: 1.17s	remaining: 40ms
# 967:	learn: 0.4559706	total: 1.17s	remaining: 38.8ms
# 968:	learn: 0.4558575	total: 1.17s	remaining: 37.6ms
# 969:	learn: 0.4557355	total: 1.18s	remaining: 36.4ms
# 970:	learn: 0.4556355	total: 1.18s	remaining: 35.1ms
# 971:	learn: 0.4554981	total: 1.18s	remaining: 33.9ms
# 972:	learn: 0.4553048	total: 1.18s	remaining: 32.7ms
# 973:	learn: 0.4551428	total: 1.18s	remaining: 31.5ms
# 974:	learn: 0.4549990	total: 1.18s	remaining: 30.3ms
# 975:	learn: 0.4548472	total: 1.18s	remaining: 29.1ms
# 976:	learn: 0.4547242	total: 1.18s	remaining: 27.9ms
# 977:	learn: 0.4546261	total: 1.19s	remaining: 26.7ms
# 978:	learn: 0.4544714	total: 1.19s	remaining: 25.5ms
# 979:	learn: 0.4542780	total: 1.19s	remaining: 24.2ms
# 980:	learn: 0.4541620	total: 1.19s	remaining: 23ms
# 981:	learn: 0.4540270	total: 1.19s	remaining: 21.8ms
# 982:	learn: 0.4538906	total: 1.19s	remaining: 20.6ms
# 983:	learn: 0.4537876	total: 1.19s	remaining: 19.4ms
# 984:	learn: 0.4536060	total: 1.19s	remaining: 18.2ms
# 985:	learn: 0.4534480	total: 1.2s	remaining: 17ms
# 986:	learn: 0.4533127	total: 1.2s	remaining: 15.8ms
# 987:	learn: 0.4531175	total: 1.2s	remaining: 14.6ms
# 988:	learn: 0.4529789	total: 1.2s	remaining: 13.3ms
# 989:	learn: 0.4528640	total: 1.2s	remaining: 12.1ms
# 990:	learn: 0.4527525	total: 1.2s	remaining: 10.9ms
# 991:	learn: 0.4526446	total: 1.2s	remaining: 9.7ms
# 992:	learn: 0.4524888	total: 1.2s	remaining: 8.49ms
# 993:	learn: 0.4523900	total: 1.21s	remaining: 7.28ms
# 994:	learn: 0.4522566	total: 1.21s	remaining: 6.06ms
# 995:	learn: 0.4521202	total: 1.21s	remaining: 4.85ms
# 996:	learn: 0.4519821	total: 1.21s	remaining: 3.64ms
# 997:	learn: 0.4518344	total: 1.21s	remaining: 2.42ms
# 998:	learn: 0.4515960	total: 1.21s	remaining: 1.21ms
# 999:	learn: 0.4514802	total: 1.21s	remaining: 0us
# ----------------------------------------------------------------------------------------------------
# Model name: CatBoostClassifier
# accuracy_score: 0.6475548060708263
# roc_auc_score: 0.5465282925623919
# precision_score: 0.5263157894736842
# f1_score: 0.2768166089965398
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### XGBOOST

# %%
models.append(classify(df,0.2,XGBClassifier(),"XGBClassifier"))
# Out:
# ----------------------------------------------------------------------------------------------------
# Model name: XGBClassifier
# accuracy_score: 0.6602023608768971
# roc_auc_score: 0.5832926585066708
# precision_score: 0.5210727969348659
# f1_score: 0.40296296296296297
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### LGBM

# %%
models.append(classify(df,0.2,LGBMClassifier(),"LGBMClassifier"))
# Out:
# [LightGBM] [Info] Number of positive: 1626, number of negative: 3118
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1181
# [LightGBM] [Info] Number of data points in the train set: 4744, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.342749 -> initscore=-0.651069
# [LightGBM] [Info] Start training from score -0.651069
# ----------------------------------------------------------------------------------------------------
# Model name: LGBMClassifier
# accuracy_score: 0.654300168634064
# roc_auc_score: 0.5658775750294109
# precision_score: 0.509009009009009
# f1_score: 0.3553459119496855
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Comparision

# %%
compare_model_results(models)
